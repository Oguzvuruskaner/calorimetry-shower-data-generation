# %%
# %matplotlib inline

# %%
import seaborn as sns
from os.path import join
import numpy as np
import matplotlib.pyplot as plt

# %%
__TESTED_DATASETS__ = [
    "hit_x_combined",
    "hit_y_combined",
    "hit_z_combined",
    "hit_e_combined",
]

# %%
fig,ax = plt.subplots(1,2)

fig.suptitle('hit_x plots', fontsize=16)

data = np.load(join("npy","hit_x_combined_1000000.npy"))
sns.distplot(data,kde=False,ax=ax[0])
ax[0].set_title("1000000 Samples")

sample_mean = np.mean(data)
sample_std = np.std(data)
sample_max = np.max(data)
sample_min = np.min(data)

data = np.load(join("npy","hit_x_combined.npy"))
sns.distplot(data,kde=False,ax=ax[1])
ax[1].set_title("Original data")

original_mean = np.mean(data)
original_std = np.std(data)
original_max = np.max(data)
original_min = np.min(data)

mean_difference = abs(original_mean-sample_mean)
std_difference = abs(original_std-sample_std)
max_difference = abs(origina_max-sample_max)
min_difference = abs(origina_min-sample_min)

print("      Sample    Original    Difference")
print("Mean  {:.3f}    {:.3f}      {:.3f}".format(sample_mean,original_mean,mean_difference))
print("Std   {:.3f}    {:.3f}      {:.3f}".format(sample_std,original_std,std_difference))
print("Max   {:.3f}    {:.3f}      {:.3f}".format(sample_max,original_max,max_difference))
print("Min   {:.3f}    {:.3f}      {:.3f}".format(sample_min,original_min,min_difference))
# Out:
#       Sample    Original    Difference
# Mean  0.226    0.231      0.005
# Std   47.670    47.515      0.155

# %%
fig,ax = plt.subplots(1,2)

fig.suptitle('hit_y plots', fontsize=16)

data = np.load(join("npy","hit_y_combined_1000000.npy"))
sns.distplot(data,kde=False,ax=ax[0])
ax[0].set_title("1000000 Samples")

sample_mean = np.mean(data)
sample_std = np.std(data)

data = np.load(join("npy","hit_y_combined.npy"))
sns.distplot(data,kde=False,ax=ax[1])
ax[1].set_title("Original data")

original_mean = np.mean(data)
original_std = np.std(data)

mean_difference = abs(original_mean-sample_mean)
std_difference = abs(original_std-sample_std)

print("      Sample    Original    Difference")
print("Mean  {:.3f}    {:.3f}      {:.3f}".format(sample_mean,original_mean,mean_difference))
print("Std   {:.3f}    {:.3f}      {:.3f}".format(sample_std,original_std,std_difference))
# Out:
#       Sample    Original    Difference
# Mean  -0.039    -0.030      0.009
# Std   45.660    45.677      0.017

# %%
fig,ax = plt.subplots(1,2)

fig.suptitle('hit_z plots', fontsize=16)

data = np.load(join("npy","hit_z_combined_1000000.npy"))
sns.distplot(data,kde=False,ax=ax[0])
ax[0].set_title("1000000 Samples")

sample_mean = np.mean(data)
sample_std = np.std(data)

data = np.load(join("npy","hit_z_combined.npy"))
sns.distplot(data,kde=False,ax=ax[1])
ax[1].set_title("Original data")

original_mean = np.mean(data)
original_std = np.std(data)

mean_difference = abs(original_mean-sample_mean)
std_difference = abs(original_std-sample_std)

print("      Sample    Original    Difference")
print("Mean  {:.3f}    {:.3f}      {:.3f}".format(sample_mean,original_mean,mean_difference))
print("Std   {:.3f}    {:.3f}      {:.3f}".format(sample_std,original_std,std_difference))
# Out:
#       Sample    Original    Difference
# Mean  196.711    196.752      0.040
# Std   71.468    71.534      0.066

# %%
fig,ax = plt.subplots(1,2)

fig.suptitle('hit_e plots', fontsize=16)

data = np.load(join("npy","hit_e_combined_1000000.npy"))
sns.distplot(data,kde=False,ax=ax[0])
ax[0].set_title("1000000 Samples")

sample_mean = np.mean(data)
sample_std = np.std(data)

data = np.load(join("npy","hit_e_combined.npy"))
sns.distplot(data,kde=False,ax=ax[1])
ax[1].set_title("Original data")

original_mean = np.mean(data)
original_std = np.std(data)

mean_difference = abs(original_mean-sample_mean)
std_difference = abs(original_std-sample_std)

print("      Sample    Original    Difference")
print("Mean  {:.3f}    {:.3f}      {:.3f}".format(sample_mean,original_mean,mean_difference))
print("Std   {:.3f}    {:.3f}      {:.3f}".format(sample_std,original_std,std_difference))
# Out:
#       Sample    Original    Difference
# Mean  0.000    0.000      0.000
# Std   0.001    0.001      0.000
